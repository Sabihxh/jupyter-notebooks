# %% [markdown]
# ## Energy Performance of Buildings Data Cambridge

# %% [markdown]
# ### Data Source
#
# https://epc.opendatacommunities.org/domestic/search?address=&postcode=&local-authority=&constituency=&from-month=1&from-year=2008&to-month=12&to-year=2019
#
# Data contains 18,000,000 records, where each row is the energy performance of a building/property in England and Wales.

# %%
import io

import pandas as pd
import requests

# %%
token = 'c2FiaWhoYXNhbjEyQGhvdG1haWwuY28udWs6MjEzYzNjM2NhYWZjZjkwOWVkZDFmN2FmMThjZWYyNGYyMWNhNDgzZQ=='
headers = {
    "Authorization": "Basic c2FiaWhoYXNhbjEyQGhvdG1haWwuY28udWs6MjEzYzNjM2NhYWZjZjkwOWVkZDFmN2FmMThjZWYyNGYyMWNhNDgzZQ==",
    "Accept": "text/csv"
}

         
url = "https://epc.opendatacommunities.org/api/v1/domestic/search?local-authority=E07000008"

local_authority = {'Cambridge': 'E07000008'}

# %%
request = requests.get(url, headers=headers)

# %%
pd.read_json(request.json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-e1a0f994ef92> in <module>()
# ----> 1 pd.read_json(request.json())
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     406     compression = _infer_compression(path_or_buf, compression)
#     407     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 408         path_or_buf, encoding=encoding, compression=compression,
#     409     )
#     410
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     216     if not is_file_like(filepath_or_buffer):
# ...

# %%
# pd.read_csv(io.FileIO request.content)
_bytes = io.BytesIO(request.content)

# %%
pd.read_csv(_bytes)
# Out:
#                                  lmk-key                   address1  \
# 0      349901528132019083107440752768901        Flat 9 Tamara House
# 1       72404438132019083112194130768807            8, Marion Close
# 2     1743740419902019083111231868612388         13, Craister Court
# 3      203577290712019083114463691210252           74, Brackyn Road
# 4       85528919242019083115545140617998             8, Gilpin Road
# 5      184638239442019083116072052417508    10, Ravensworth Gardens
# 6      133852868132019083111460013768302              46, Riverside
# 7     1747534061852019083115070694210968            51, Dudley Road
# 8      182704909722019083117263053098881         227, Victoria Road
# 9      359606519102019083012454164717208   Flat 6 Springfield Court
# 10    1742859589762019083016025226108601              33a, Nuns Way
# 11    1742877508752019083016024090710161          40a, Cameron Road
# 12    1747393560712019083015460894710766            8a, Wiles Close
# ...
