# %%
# %matplotlib inline

import matplotlib.pyplot as plt
# plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# %%
FIGSIZE = (10, 5)

# %%
iris = load_iris()
features = iris.data.T

plt.figure(figsize=FIGSIZE)

plt.scatter(
    features[0], 
    features[1], 
    alpha=0.2, 
    s=100*features[3],
    c=iris.target,
    cmap='viridis',
)


plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# **Tip: Use plt.plot (more efficient) instead of plt.scatter for large datasets**

# %% [markdown]
# ### Error Bars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + (dy * np.random.randn(50))

plt.figure(figsize=FIGSIZE)
plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.figure(figsize=FIGSIZE)
plt.errorbar(
    x, y, yerr=dy, 
    fmt='o', 
    color='black',
    ecolor='lightgray',
    elinewidth=3,
    capsize=0,
);

# %% [markdown]
# ### Continous Errors

# %%
from sklearn.gaussian_process import GaussianProcessRegressor

model = lambda x: x * np.sin(x)
xdata = np.array([1,3,5,6,8])
ydata = model(xdata)

gp = GaussianProcessRegressor(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1e-1, random_state=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-1cdcd6316fac> in <module>()
#       5 ydata = model(xdata)
#       6
# ----> 7 gp = GaussianProcessRegressor(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1e-1, random_state=100)
#
# TypeError: __init__() got an unexpected keyword argument 'corr'

# %%
GaussianProcessRegressor?

# %%
ic
